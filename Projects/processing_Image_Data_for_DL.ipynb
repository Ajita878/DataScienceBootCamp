# %% [markdown]
# **Topics**
#
# Reading an image file and converting it to a numpy array
#
# Resizing an image
#
# RGB TO Grayscale conversion

# %%
#getting an image using webget

# %%
# !wget 'https://www.rd.com/wp-content/uploads/2018/02/30_Adorable-Puppy-Pictures-that-Will-Make-You-Melt_124167640_YamabikaY.jpg?fit=700%2C467'
# Out:
# --2024-03-04 19:32:48--  https://www.rd.com/wp-content/uploads/2018/02/30_Adorable-Puppy-Pictures-that-Will-Make-You-Melt_124167640_YamabikaY.jpg?fit=700%2C467
# Resolving www.rd.com (www.rd.com)... 172.64.144.126, 104.18.43.130, 2606:4700:4400::ac40:907e, ...
# Connecting to www.rd.com (www.rd.com)|172.64.144.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43603 (43K) [image/jpeg]
# Saving to: ‘30_Adorable-Puppy-Pictures-that-Will-Make-You-Melt_124167640_YamabikaY.jpg?fit=700,467’
#
# 30_Adorable-Puppy-P 100%[===================>]  42.58K  --.-KB/s    in 0.008s
#
# 2024-03-04 19:32:48 (4.93 MB/s) - ‘30_Adorable-Puppy-Pictures-that-Will-Make-You-Melt_124167640_YamabikaY.jpg?fit=700,467’ saved [43603/43603]

# %% [markdown]
# **Libraries that will be used for image processing**
#
# matplotlib.image
#
# Pillow(PIL)
#
# OpenCV (cv2)

# %%
#importing the image from module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module
img =  mpimg.imread('/content/Dog.jpg') #imread means image read

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape) #it gives height, width and color(RGB)
# Out:
# (467, 700, 3)

# %%
print(img) #it gives all the values of numpy array
# Out:
# [[[200 171  54]
#   [199 170  53]
#   [197 170  53]
#   ...
#   [190 174  79]
#   [191 175  80]
#   [191 175  80]]
#
#  [[205 175  61]
#   [202 175  60]
#   [201 174  59]
#   ...
#   [191 175  80]
#   [192 176  81]
#   [193 177  82]]
#
#  [[211 183  73]
#   [211 183  73]
#   [209 181  71]
#   ...
#   [190 174  78]
#   [190 174  78]
#   [191 175  79]]
#
#  ...
#
#  [[198 200  37]
#   [199 202  37]
#   [201 204  39]
#   ...
#   [127 156  48]
#   [136 164  61]
#   [140 168  68]]
#
#  [[198 201  34]
#   [199 202  33]
#   [201 204  35]
#   ...
#   [129 157  46]
#   [137 164  59]
#   [142 168  67]]
#
#  [[198 201  34]
#   [199 202  33]
#   [201 204  35]
#   ...
#   [129 157  46]
#   [138 165  60]
#   [143 169  68]]]

# %%
# displaying the image from numpy array
img_plot =plt.imshow(img)

# %% [markdown]
# Resizing an image using Pillow Library

# %%
from PIL import Image

# %%
img = Image.open('/content/Dog.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
type(img_res)
# Out:
# numpy.ndarray

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Converting RGB images to Grayscale image using OpenCV

# %%
#importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/Dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (467, 700, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape #grayscale image has only one channel so we don't have third value here.
# Out:
# (467, 700)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in collab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x467>

# %%
#saving thegrayscale image
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
